# %% [markdown]
# # Tarea 3

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Primera fase - Pre Procesado
#
# Durante esta fase se empieza con la carga de los datos, posteriormente descripción de las variables y si tenemos datos perdidos o NA.
#
# Posteriormente ante esa presencia se hace un estudio de las variables y se trata de lidiar con los datos perdidos, ya sea por metodos de estimación de los datos o si descarta del todo las observaciones

# %%
df = pd.read_csv("weatherAUS.csv")

# %%
df.shape
# Out:
# (142193, 24)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4            NaN           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 142188       1024.7       1021.2       NaN       NaN      9.4     20.9
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 0              No      0.0            No
# 1              No      0.0            No
# 2              No      0.0            No
# 3              No      1.0            No
# 4              No      0.2            No
# ...           ...      ...           ...
# 142188         No      0.0            No
# 142189         No      0.0            No
# 142190         No      0.0            No
# 142191         No      0.0            No
# 142192         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
df[df["Evaporation"].isnull()==False]
# Out:
#               Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01      Cobar     17.9     35.2       0.0         12.0
# 5940    2009-01-02      Cobar     18.4     28.9       0.0         14.8
# 5941    2009-01-03      Cobar     15.5     34.1       0.0         12.6
# 5942    2009-01-04      Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05      Cobar     21.9     38.4       0.0         11.4
# ...            ...        ...      ...      ...       ...          ...
# 140667  2017-06-19  Katherine     12.4     32.0       0.0          6.4
# 140668  2017-06-20  Katherine     15.0     32.0       0.0          9.6
# 140669  2017-06-21  Katherine     15.4     31.5       0.0          3.6
# 140670  2017-06-22  Katherine     12.2     31.5       0.0          4.0
# 140671  2017-06-23  Katherine     14.9     31.5       0.0          6.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 5939        12.3         SSW           48.0        ENE  ...        13.0
# 5940        13.0           S           37.0        SSE  ...         8.0
# 5941        13.3          SE           30.0        NaN  ...         7.0
# 5942        10.6         NNE           46.0        NNE  ...        22.0
# 5943        12.2         WNW           31.0        WNW  ...        22.0
# ...          ...         ...            ...        ...  ...         ...
# 140667       NaN          SE           41.0         SE  ...         NaN
# 140668       NaN           E           35.0         SE  ...         NaN
# 140669       NaN         ESE           43.0        ESE  ...         NaN
# 140670       NaN         ESE           37.0         SE  ...         NaN
# 140671       NaN         ESE           41.0         SE  ...         NaN
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 5939         1006.3       1004.4       2.0       5.0     26.6     33.4
# 5940         1012.9       1012.1       1.0       1.0     20.3     27.0
# 5941            NaN       1011.6       NaN       1.0      NaN     32.7
# 5942         1012.3       1009.2       1.0       6.0     28.7     34.9
# 5943         1012.7       1009.1       1.0       5.0     29.1     35.6
# ...             ...          ...       ...       ...      ...      ...
# 140667       1016.6       1012.3       0.0       NaN     20.3      NaN
# 140668       1015.9       1012.1       0.0       NaN     21.8      NaN
# 140669       1016.6       1012.7       0.0       NaN     21.6      NaN
# 140670       1017.1       1012.8       0.0       NaN     19.9      NaN
# 140671       1016.1       1011.8       0.0       NaN     22.8      NaN
#
#         RainToday  RISK_MM  RainTomorrow
# 5939           No      0.0            No
# 5940           No      0.0            No
# 5941           No      0.0            No
# 5942           No      0.0            No
# 5943           No      0.0            No
# ...           ...      ...           ...
# 140667         No      0.0            No
# 140668         No      0.0            No
# 140669         No      0.0            No
# 140670         No      0.0            No
# 140671         No      0.0            No
#
# [81350 rows x 24 columns]

# %%
d= df[df["Evaporation"].isnull()==False]
d["Evaporation"].plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c0fc3a58be75> in <module>
# ----> 1 plot.show()
#
# NameError: name 'plot' is not defined
